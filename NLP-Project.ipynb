# %% [markdown]
# #Project

# %%
# !pip install transformers
import transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 7.2/7.2 MB 56.4 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 236.8/236.8 kB 26.0 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 7.8/7.8 MB 79.1 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 1.3/1.3 MB 69.6 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased", from_tf=True)
sa= pipeline("sentiment-analysis", tokenizer=tokenizer, model=model, padding="max_length", truncation=True)

p = sa("bu telefon modelleri Ã§ok kaliteli , her parÃ§asÄ± Ã§ok Ã¶zel bence")
print(p)
# [{'label': 'positive', 'score': 0.9871089}]
print(p[0]['label'] == 'LABEL_1')
# True

p = sa("Film Ã§ok kÃ¶tÃ¼ ve Ã§ok sahteydi")
print(p)
# [{'label': 'negative', 'score': 0.9975505}]
print(p[0]['label'] == 'LABEL_1')
# False
# Out:
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'positive', 'score': 0.983146607875824}]
# False
# [{'label': 'negative', 'score': 0.9990053772926331}]
# False

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/encoded-hepsiburada-product-comments.csv', sep=",")

# %%
data.columns = ['Ã¼rÃ¼n', 'yorum', 'yÄ±ldÄ±z', '?', '??']

# %%
data
# Out:
#                                                      Ã¼rÃ¼n  \
# 0                                                Uno Flip
# 1                                                Uno Flip
# 2                                                Uno Flip
# 3                                                Uno Flip
# 4                                                Uno Flip
# ...                                                   ...
# 947025  KÄ±raÃ§ Dekoratif Duvar Dekorasyon TÃ¼y Desen Ayn...
# 947026  KÄ±raÃ§ Dekoratif Duvar Dekorasyon TÃ¼y Desen Ayn...
# 947027  KÄ±raÃ§ Dekoratif Duvar Dekorasyon TÃ¼y Desen Ayn...
# 947028  KÄ±raÃ§ Dekoratif Duvar Dekorasyon TÃ¼y Desen Ayn...
# 947029  KÄ±raÃ§ Dekoratif Duvar Dekorasyon TÃ¼y Desen Ayn...
#
#                                                     yorum  yÄ±ldÄ±z   ?  ??
# 0       Merhaba, \nDaha Ã¶nce yapmÄ±ÅŸ olduÄŸum yorumda ka...       5   3   1
# 1                                 Gayet gÃ¼zel hÄ±zlÄ± geldi       5   4   4
# ...

# %% [markdown]
# #Veriyi kÃ¼Ã§Ã¼ltme

# %%
yorum = data.yorum[0]
yorum
# Out:
# "Merhaba, \nDaha Ã¶nce yapmÄ±ÅŸ olduÄŸum yorumda kartlardan birkaÃ§ tanesinin hatalÄ± Ã§Ä±ktÄ±ÄŸÄ±nÄ± yazmÄ±ÅŸtÄ±m. ÃœrÃ¼nÃ¼n satÄ±cÄ±sÄ± (megahediyelik) benimle iletiÅŸime geÃ§erek yeni Ã¼rÃ¼n gÃ¶ndereceÄŸini belirtti. YanÄ±nda bir de hediye gÃ¶ndermiÅŸler, bu nazik davranÄ±ÅŸlarÄ± iÃ§in kendilerine teÅŸekkÃ¼r ediyorum. Kargo hÄ±zlÄ±ydÄ±, megahediyelik'ten ÅŸaÅŸmayÄ±n ğŸ‘ğŸ»"

# %%
p = sa(yorum)
p[0]['label']
# Out:
# 'negative'

# %%
def sent_analyzer(yorum):
  p = sa(yorum)
  return p[0]['label']

# %%
sub_data = data[:10]

# %%
sub_data
# Out:
#                                                 Ã¼rÃ¼n  \
# 0                                           Uno Flip
# 1                                           Uno Flip
# 2                                           Uno Flip
# 3                                           Uno Flip
# 4                                           Uno Flip
# 5  ToptancÄ± KapÄ±nda 7 Renk DeÄŸiÅŸtiren AlarmlÄ± Dij...
# 6                                           Uno Flip
# 7                                           Uno Flip
# 8                                           Uno Flip
# 9                                           Uno Flip
#
#                                                yorum  yÄ±ldÄ±z  ?  ??
# 0  Merhaba, \nDaha Ã¶nce yapmÄ±ÅŸ olduÄŸum yorumda ka...       5  3   1
# 1                            Gayet gÃ¼zel hÄ±zlÄ± geldi       5  4   4
# 2  Klasik ve diÄŸer uno da gayet gÃ¼zeldi bu da Ã§ok...       5  8   2
# 3  Kart ile alakalÄ± bir iki defo sorunu vardÄ±, yo...       5  0   0
# ...

# %%
sub_data['duygu'] = sub_data['yorum'].apply(sent_analyzer)
# Out:
# <ipython-input-13-bb883a424068>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data['duygu'] = sub_data['yorum'].apply(sent_analyzer)

# %%
sub_data
# Out:
#                                                 Ã¼rÃ¼n  \
# 0                                           Uno Flip
# 1                                           Uno Flip
# 2                                           Uno Flip
# 3                                           Uno Flip
# 4                                           Uno Flip
# 5  ToptancÄ± KapÄ±nda 7 Renk DeÄŸiÅŸtiren AlarmlÄ± Dij...
# 6                                           Uno Flip
# 7                                           Uno Flip
# 8                                           Uno Flip
# 9                                           Uno Flip
#
#                                                yorum  yÄ±ldÄ±z  ?  ??     duygu
# 0  Merhaba, \nDaha Ã¶nce yapmÄ±ÅŸ olduÄŸum yorumda ka...       5  3   1  negative
# 1                            Gayet gÃ¼zel hÄ±zlÄ± geldi       5  4   4  negative
# 2  Klasik ve diÄŸer uno da gayet gÃ¼zeldi bu da Ã§ok...       5  8   2  positive
# ...

# %% [markdown]
# #Daha bÃ¼yÃ¼k bir subset

# %%
sub_data = data[:1000]

# %%
sub_data
# Out:
#                                                   Ã¼rÃ¼n  \
# 0                                             Uno Flip
# 1                                             Uno Flip
# 2                                             Uno Flip
# 3                                             Uno Flip
# 4                                             Uno Flip
# ..                                                 ...
# 995  Bio-oil Ã‡atlak KarÅŸÄ±tÄ± & Nemlendirici Cilt Bak...
# 996  Bio-oil Ã‡atlak KarÅŸÄ±tÄ± & Nemlendirici Cilt Bak...
# 997  Bio-oil Ã‡atlak KarÅŸÄ±tÄ± & Nemlendirici Cilt Bak...
# 998                        OtacÄ± DoÄŸal GÃ¼l Suyu 150 ml
# 999  Bioderma Sebium Foaming Gel - Karma&YaÄŸlÄ± Cilt...
#
#                                                  yorum  yÄ±ldÄ±z  ?  ??
# 0    Merhaba, \nDaha Ã¶nce yapmÄ±ÅŸ olduÄŸum yorumda ka...       5  3   1
# 1                              Gayet gÃ¼zel hÄ±zlÄ± geldi       5  4   4
# ...

# %%
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 81.4/81.4 kB 3.6 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 474.6/474.6 kB 16.7 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 110.5/110.5 kB 14.0 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 212.5/212.5 kB 25.3 MB/s eta 0:00:00
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 134.3/134.3 kB 17.3 MB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import train_test_split
validation_size = 0.2
train_df, test_df = train_test_split(sub_data, test_size=validation_size, random_state=42)

# %%
test_df.shape
# Out:
# (200, 5)

# %%
train_df.shape
# Out:
# (800, 5)

# %%
from datasets import Dataset
hg_test_data = Dataset.from_pandas(test_df)
hg_train_data = Dataset.from_pandas(train_df)

# %%
hg_train_data[0]
# Out:
# {'Ã¼rÃ¼n': 'Ks Games Metropol Emlak Ticareti Oyunu',
#  'yorum': 'Oyun muadillerini aratmÄ±yor hatta fark yok diye biliriz. Paketleme gayet gÃ¼zel, oyun sahasÄ±, piyonlar kartlar gayet gÃ¼zel, bir tek oyun parasÄ± biraz daha kaliteli olsa iyi olurdu. Ã‡Ã¼nkÃ¼ en Ã§ok elde dolaÅŸan ve kullanÄ±lan o. Oyun talimatlarÄ± gayet aÃ§Ä±klayÄ±cÄ±. Muadiline o kadar paralar vermek saÃ§ma olur. Ki aslÄ±nda muadili ile kÄ±yaslamak belki de haksÄ±zlÄ±k olacak derecede tatmin edici bir Ã¼rÃ¼n.',
#  'yÄ±ldÄ±z': 5,
#  '?': 6,
#  '??': 0,
#  '__index_level_0__': 29}

# %%
def tokenize_dataset(data):
  return tokenizer(data["yorum"],
                   max_length = 32,
                   truncation = True,
                   padding = "max_length")
# Tokenize the dataset
dataset_train = hg_train_data.map(tokenize_dataset)
dataset_test = hg_test_data.map(tokenize_dataset)
dataset_train.with_format("tensorflow")
dataset_test.with_format("tensorflow")
# Out:
# ...
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Dataset({
#     features: ['Ã¼rÃ¼n', 'yorum', 'yÄ±ldÄ±z', '?', '??', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 200
# })

# %%
import evaluate

# %%
from transformers import TrainingArguments, Trainer, EarlyStoppingCallback, TextClassificationPipeline

# %%
def compute_metrics(eval_pred):
  metric = evaluate.load("accuracy")
  logits, labels = eval_pred
  predictions = np.argmax(logits, axis=1)
  return metric.compute(predictions=predictions, references=labels)

# %%
# !pip install accelerate -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 227.6/227.6 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    output_dir = "/content/our-model",
    learning_rate=2e-5,
    per_device_train_batch_size= 64,
    per_device_eval_batch_size = 16,
    num_train_epochs = 2,
    weight_decay = 0.01,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    load_best_model_at_end = True,
    push_to_hub = False
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-0518ea5ff407> in <cell line: 2>()
#       1 from transformers import TrainingArguments
# ----> 2 training_args = TrainingArguments(
#       3     output_dir = "/content/our-model",
#       4     learning_rate=2e-5,
#       5     per_device_train_batch_size= 64,
#
# ...

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer)

# %%
from transformers import Trainer
trainer = Trainer(
    model=model,
    train_dataset=dataset_train,
    eval_dataset=dataset_test,
    compute_metrics=compute_metrics,
    data_collator = data_collator,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=1)]
)
trainer.train()

# %%
sub_data['duygu'] = sub_data['yorum'].apply(sent_analyzer)
